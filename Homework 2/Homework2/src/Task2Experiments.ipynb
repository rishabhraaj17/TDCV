# %% [markdown]
# ## TASK 2 - Experiments

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

import seaborn as sns
sns.set()

# %% [markdown]
# ### Changing MaxDepth Parameter

# %%
file_path = "../task2_maxDepth.csv"

# %%
max_depth_dataframe = pd.read_csv(file_path)

# %%
sns.lineplot(x='MaxDepth', y='Accuracy', data=max_depth_dataframe)

# %% [markdown]
# ### Changing Number of D-Trees

# %%
file_path = "../task2_trees.csv"

# %%
trees_dataframe = pd.read_csv(file_path)

# %%
sns.lineplot(x='TreeCount', y='Accuracy', data=trees_dataframe)
