# %% [markdown]
# # Precision Recall Curve for Task 3

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

import seaborn as sns

# %%
file_path = "../output/Trees-80_subsetPercent-50-scaleFactor_1.1-undersampling_0-augment_1-strideX_2-strideY_2-NMS_MIN_0.1-NMS_Max_0.5-NMS_CONF_0.6/predictionRecallValues.csv"

# %%
pr_dataframe = pd.read_csv(file_path)

# %%
pr_dataframe.head(15)
# Out:
#     Precision    Recall
# 0    0.020964  0.778157
# 1    0.020964  0.778157
# 2    0.020964  0.778157
# 3    0.020964  0.778157
# 4    0.020964  0.778157
# 5    0.020964  0.778157
# 6    0.020624  0.781690
# 7    0.021463  0.762411
# 8    0.022207  0.729730
# 9    0.023831  0.704846
# 10   0.032828  0.772277
# 11   0.050428  0.828125
# 12   0.062326  0.761364
# 13   0.076763  0.689441
# 14   0.114512  0.668874

# %%
sns.set()

# %%
sns.lineplot(x='Recall', y='Precision', data=pr_dataframe)

# %% [markdown]
# ### More Experiments

# %%
file_path = "../output/metrics_tree56_undersampled.csv"

# %%
undersampled_tree_56 = pd.read_csv(file_path)

# %%
sns.lineplot(x='Recall', y='Precision', data=undersampled_tree_56)
