# %% [markdown]
# # Precision Recall Curve for Task 3

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

import seaborn as sns

# %%
file_path = "../output/backups/TreesCount_50_Percent_50_underSampling_0_DataAugment_1_strideX_6_strideY_6/metrics.csv"

# %%
pr_dataframe = pd.read_csv(file_path)

# %%
pr_dataframe.head(15)
# Out:
#     Precision    Recall
# 0    0.099790  0.678571
# 1    0.125676  0.650350
# 2    0.151757  0.673759
# 3    0.169261  0.630435
# 4    0.206161  0.625899
# 5    0.220588  0.555556
# 6    0.249110  0.526316
# 7    0.290043  0.503759
# 8    0.306011  0.421053
# 9    0.280576  0.295455
# 10   0.336735  0.250000
# 11   0.347222  0.189394
# 12   0.395833  0.143939

# %%
sns.set()

# %%
sns.lineplot(x='Recall', y='Precision', data=pr_dataframe)

# %% [markdown]
# #### 60 Trees

# %%
file_path = "../output/TreesCount_60_subsetPercent_50_scaleFactor_1.1_underSampling_0_DataAugment_1_strideX_6_strideY_6_NMS_MIN_0.3_NMS_Max_0.55_NMS_CONF_0.6/metrics.csv"

# %%
tree_60_dataframe = pd.read_csv(file_path)

# %%
sns.lineplot(x='Recall', y='Precision', data=tree_60_dataframe)

# %% [markdown]
# ### More Experiments

# %%
file_path = "../output/metrics_tree56_undersampled.csv"

# %%
undersampled_tree_56 = pd.read_csv(file_path)

# %%
sns.lineplot(x='Recall', y='Precision', data=undersampled_tree_56)
